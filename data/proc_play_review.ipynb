# %%
import json
import glob
import os.path
import pandas as pd
import numpy as np

# %%
def gettblData(tbl):# hitter 정보 테이블
    li = []
    for row in tbl['rows']:
        subli = []
        for r in row['row']:
            subli.append(r['Text'])
        li.append(subli)
    return pd.DataFrame(li)

# 타자 기록 2팀.
def get_hitter_record(path):
    boxscoreData = json.loads(open(path, 'r', encoding='utf-8-sig').read())

    result = []
    for hitter in boxscoreData['arrHitter']:
        df_hitter_record = pd.DataFrame()
        # tbl1 # 이닝/포지션/이름
        # tbl2 # 이닝별 성적
        # tbl3 # 타수 안타 타점 득점 타율
        # hitter = boxscoreData['arrHitter'][1] # table1 ~ 3
        for key in hitter: # 3구역으로 구성된 hitter 테이블을 하나씩 pick
            tbl = json.loads(hitter[key])
            df_hitter_record = pd.concat([df_hitter_record, gettblData(tbl)], axis=1)

        # 컬럼 이름 지정
        idx = ['이닝','포지션','선수명']
        idx.extend([str(i+1) for i in list(range(boxscoreData['realMaxInning']))])
        idx.extend(['타수','안타','타점','득점','타율'])
        df_hitter_record.columns = idx
        result.append(df_hitter_record)
    return result

def get_Pitcher_record(path):
    boxscoreData = json.loads(open(path, 'r', encoding='utf-8-sig').read())
    result = []

    for pitcher in boxscoreData['arrPitcher']:
        tbl = json.loads(pitcher['table'])
        pitcher_df = gettblData(tbl)
        pitcher_df.columns = ['선수명','등판','결과','승','패','세','이닝','타자','투구수','타수','피안타','홈런','4사구','삼진','실점','자책','평균자책점']
        result.append(pitcher_df)
    return result

def get_Summary(path):
    boxscoreData = json.loads(open(path, 'r', encoding='utf-8-sig').read())
    data = json.loads(boxscoreData['tableEtc'])
    return gettblData(data)

def getScoreBoard(path):
    data = json.loads(open(path, 'r', encoding='utf-8-sig').read())

    tbl1_data = json.loads(data['table1'])
    tbl2_data = json.loads(data['table2'])
    tbl3_data = json.loads(data['table3'])

    scoreboardDF = {}
    scoreboardDF['away_승패'] = tbl1_data['rows'][0]['row'][0]['Text']
    scoreboardDF['away_전적'] = tbl1_data['rows'][0]['row'][1]['Text'].split('</span>')[1]
    inning = 1
    for i in tbl2_data['rows'][0]['row']:
        scoreboardDF['away_' + str(inning)] = i['Text']
        inning += 1
    scoreboardDF['away_R'] = tbl3_data['rows'][0]['row'][0]['Text'] # R 점수
    scoreboardDF['away_H'] = tbl3_data['rows'][0]['row'][1]['Text'] # H 안타
    scoreboardDF['away_E'] = tbl3_data['rows'][0]['row'][2]['Text'] # E 에러
    scoreboardDF['away_B'] = tbl3_data['rows'][0]['row'][3]['Text'] # 볼넷 수

    scoreboardDF['home_승패'] = tbl1_data['rows'][1]['row'][0]['Text']
    scoreboardDF['home_전적'] = tbl1_data['rows'][1]['row'][1]['Text'].split('</span>')[1]
    inning = 1
    for i in tbl2_data['rows'][1]['row']:
        scoreboardDF['home_' + str(inning)] = i['Text']
        inning += 1
    scoreboardDF['home_R'] = tbl3_data['rows'][1]['row'][0]['Text'] # R 점수
    scoreboardDF['home_H'] = tbl3_data['rows'][1]['row'][1]['Text'] # H 안타
    scoreboardDF['home_E'] = tbl3_data['rows'][1]['row'][2]['Text'] # E 에러
    scoreboardDF['home_B'] = tbl3_data['rows'][1]['row'][3]['Text'] # 볼넷 수

    return pd.concat([pd.DataFrame(data, index=[0]), pd.DataFrame(scoreboardDF, index=[0])], axis=1)

# %%
# SR_ID
# 포스트 시즌 : 4
# 시범경기 : 1
# 정규시즌 : 0


dirpath = r'.\teamReviewRawData_json'

## test용 파일 경로
filename1 = r'0_2021_20210403SSWO0_GetBoxScoreScroll.json'
filename2 = r'0_2021_20210403SSWO0_GetScoreBoardScroll.json'
boxscorePath = os.path.join(dirpath, filename1)
scoreboardPath = os.path.join(dirpath, filename2)

# get_Gameinfo(scoreboardPath)
# getScoreboardDataFrame(scoreboardPath) # 스코어보드

# get_Summary(boxscorePath) # 요약 정보
# get_hitter_record(boxscorePath)[0] # 타자 기록 : 원정팀
# get_hitter_record(boxscorePath)[1] # 타자 기록 : 홈팀
# get_Pitcher_record(boxscorePath)[0] # 투수 기록 : 원정팀
# get_Pitcher_record(boxscorePath)[1] # 투수 기록 : 홈팀
# Out:
#                           0
# SR_ID                     0
# G_ID          20210403SSWO0
# G_DT             2021-04-03
# SEASON_ID              2021
# HOME_NM                  키움
# HOME_ID                  WO
# AWAY_NM                  삼성
# AWAY_ID                  SS
# S_NM                     고척
# CROWD_CN              1,665
# H_W_CN                    1
# H_L_CN                    0
# H_D_CN                    0
# A_W_CN                    0
# A_L_CN                    1
# A_D_CN                    0
# T_SCORE_CN                1
# B_SCORE_CN                6
# START_TM              13:59
# END_TM                16:43
# USE_TM                 2:44
# FULL_HOME_NM        키움 히어로즈
# FULL_AWAY_NM        삼성 라이온즈
# maxInning                12

# %%
result = pd.DataFrame()

for filename in os.listdir(dirpath):
    if filename.__contains__('GetScoreBoardScroll') == False:
        continue
    path = os.path.join(dirpath,filename)
    result = result.append(getScoreBoard(path))
    print(f'>>> {path} is Load Complete!!!')


result.reset_index(drop=True, inplace=True)
# result.to_csv('playReview_ScoreBoard_Rawdata.csv', encoding='utf-8-sig', index=False)
# Out:
# >>> .\teamReviewRawData_json\0_2018_20180324HHWO0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180324KTHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180324LGNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180324LTSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180324SSOB0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180325HHWO0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180325KTHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180325LGNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180325LTSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180325SSOB0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180327HHNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180327KTSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180327LGWO0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180327LTOB0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180327SSHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180328HHNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180328KTSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180328LGWO0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180328LTOB0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180328SSHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180329HHNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180329KTSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180329LGWO0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180329LTOB0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180329SSHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180330HTLG0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180330NCLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180330OBKT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180330SKHH0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180330WOSS0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180331HTLG0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180331NCLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180331OBKT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180331SKHH0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180331WOSS0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180401HTLG0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180401NCLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180401OBKT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180401SKHH0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180401WOSS0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180403HTSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180403KTWO0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180403LGOB0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180403LTHH0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180403SSNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180404HTSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180404KTWO0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20180404LGOB0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2018_20
_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211017HHKT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211017HTOB1_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211017HTOB2_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211017LGNC1_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211017LGNC2_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211017SKLT1_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211017SKLT2_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211017WOSS0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211019KTNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211019OBSS0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211019SKHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211019WOLG0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211020KTHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211020NCSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211020WOLG0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211021HHHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211021OBSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211021WOLG0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211022HHLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211022HTNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211022KTSS0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211022OBSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211023HHLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211023HTNC1_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211023HTNC2_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211023KTSS0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211023LGOB0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211024HHLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211024HTNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211024LGOB1_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211024LGOB2_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211024SKSS0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211024WOKT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211025LTLG0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211025WOHH0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211026LGHH0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211026SKNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211026WOOB0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211027HTLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211027LGHH0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211027NCKT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211027OBSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211027SSWO0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211028HTLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211028LGHH0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211028NCKT1_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211028NCKT2_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211028OBSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211029KTWO0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211029LGLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211029OBHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211029SSNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211030KTSK0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211030LGLT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211030OBHH0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211030SSNC0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\0_2021_20211030WOHT0_GetScoreBoardScroll.json is Load Complete!!!
# >>> .\teamReviewRawData_json\6_2021_20211031KTSS0_GetScoreBoardScroll.json is Load Complete!!!

# %%
result
# Out:
#       LE_ID  SR_ID           G_ID        G_DT  SEASON_ID HOME_NM HOME_ID  \
# 0         1      0  20180324HHWO0  2018-03-24       2018      넥센      WO
# 1         1      0  20180324KTHT0  2018-03-24       2018     KIA      HT
# 2         1      0  20180324LGNC0  2018-03-24       2018      NC      NC
# 3         1      0  20180324LTSK0  2018-03-24       2018      SK      SK
# 4         1      0  20180324SSOB0  2018-03-24       2018      두산      OB
# ...     ...    ...            ...         ...        ...     ...     ...
# 2876      1      0  20211030LGLT0  2021-10-30       2021      롯데      LT
# 2877      1      0  20211030OBHH0  2021-10-30       2021      한화      HH
# 2878      1      0  20211030SSNC0  2021-10-30       2021      NC      NC
# 2879      1      0  20211030WOHT0  2021-10-30       2021     KIA      HT
# 2880      1      6  20211031KTSS0  2021-10-31       2021      삼성      SS
#
#      AWAY_NM AWAY_ID S_NM  ... home_7  home_8  home_9  home_10  home_11  \
# 0         한화      HH   고척  ...      0       0       -        -        -
# 1         KT      KT   광주  ...      0       0       0        -        -
# 2         LG      LG   마산  ...      0       2       -        -        -
# 3         롯데      LT   문학  ...      1       0       -        -        -
# 4         삼성      SS   잠실  ...      2       0       0        -        -
# ...      ...     ...  ...  ...    ...     ...     ...      ...      ...
# 2876      LG      LG   사직  ...      0       0       -        -        -
# 2877      두산      OB   대전  ...      0       0       0        -        -
# 2878      삼성      SS   창원  ...      0       0       1        -        -
# 2879      키움      WO   광주  ...      0       0       0        -        -
# 2880      KT      KT   대구  ...      0       0       0        -        -
#
#       home_12  home_R  home_H  home_E home_B
# 0           -       6      12       1      4
# 1           -       4      12       0      4
# 2           -       4       9       0      4
# 3           -       6       8       3      7
# 4           -       3       6       0      0
# ...       ...     ...     ...     ...    ...
# 2876        -       4       9       0      4
# 2877        -       3       7       2      1
# 2878        -       5      10       1      4
# 2879        -       1       5       0      0
# 2880        -       0       2       1      3
#
# [2881 rows x 69 columns]
